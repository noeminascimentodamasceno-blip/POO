# %%
from cadastro import cadastrar_cursos, cadastrar_alunos, adicionar_notas

#Etapa 1: cadastrar cursos
cursos = cadastrar_cursos()

#Etapas 2: cadastrar alunos
alunos = cadastrar_alunos(cursos)

#Etapas 3: adicionar notas
adicionar_notas(alunos)

#Exibir dados
for aluno in alunos:
    aluno.mostrar_dados()
# Out:
#  Cadastro do curso 1
#
#  Cadastro do curso 2
#
# Cadastro do aluno 1
# Escolha invalida.
# Escolha invalida.
#
# Adicionando notas para 87654321:
# A nota deve está entre 0 e 10.
# A nota deve está entre 0 e 10.
# Nome: 87654321
# Matrícula: 12345678
# Média: 10.00
# Curso de matematica, duração de 4 semestres.
